# %% [markdown]
# # Graph-based document classification
#
# * Data preprocessing
# * Build Word-word interaction graph
# * Calculate basic stats on graph
# * Visualization of graph
# * Graph representaion learning on word-word graph + visualization
# * Build Word-document interaction graph

# %%
import pandas as pd 
import numpy as np
import networkx as nx

from collections import defaultdict
import os
import torch
import torch.nn as nn
import numpy as np
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git
# !pip install -q torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# Out:
# 1.12.1+cu113
#      |████████████████████████████████| 7.9 MB 8.1 MB/s
#      |████████████████████████████████| 3.5 MB 9.9 MB/s
#   Building wheel for torch-geometric (setup.py) ... done
#      |████████████████████████████████| 2.4 MB 8.0 MB/s

# %%
! git clone https://github.com/KaiDMML/FakeNewsNet.git
# Out:
# Cloning into 'FakeNewsNet'...
# remote: Enumerating objects: 756, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 756 (delta 10), reused 11 (delta 5), pack-reused 735
# Receiving objects: 100% (756/756), 43.99 MiB | 16.07 MiB/s, done.
# Resolving deltas: 100% (154/154), done.

# %%
fake_news_data = pd.read_csv("./FakeNewsNet/dataset/politifact_fake.csv")
real_news_data = pd.read_csv("./FakeNewsNet/dataset/politifact_real.csv")
news_data = pd.concat([fake_news_data,real_news_data])
doc_content_list = news_data["title"].values

# %%
import string
import nltk
import re
nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('english')


def remove_punctuation(text):
    punctuationfree="".join([i for i in text if i not in string.punctuation+"‘"])
    return punctuationfree

def remove_stopwords(text):
    output= " ".join([i.lower() for i in text.split() if i not in stopwords])
    return output

def clean_text(text):
    text = remove_punctuation(text)
    text = remove_stopwords(text)
    return text
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
news_data["title"] = news_data["title"].apply(clean_text)
doc_content_list = news_data["title"].values

# %% [markdown]
# ## Train-test splits

# %%
from sklearn.model_selection import train_test_split

# %%
# document ids
document_ids = np.arange(news_data.shape[0])

# targtes
document_targets = [1] * fake_news_data.shape[0] + [0] * real_news_data.shape[0]
document_targets = np.array(document_targets)

train_ids, test_ids, train_target, test_target = train_test_split(
                                                document_ids,document_targets,
                                                test_size=0.2,random_state=123,stratify=document_targets
)
doc_content_list = doc_content_list[np.append(train_ids,test_ids)]

# sizes
train_size = len(train_ids)
val_size = int(0.1 * train_size)
real_train_size = train_size - val_size
test_size = len(test_ids)

# %% [markdown]
# ## Build vocabulary

# %%
# build vocabulary set and calculate word frequency
word_freq = {}
for doc_words in doc_content_list:
    words = doc_words.split()
    for word in words:
        if word in word_freq:
            word_freq[word] += 1
        else:
            word_freq[word] = 1
            

sort_orders = sorted(word_freq.items(), key=lambda x: x[1], reverse=True)
most_freq = [w[0] for w in sort_orders[:10]]
vocab = [w for w, freq in word_freq.items() if (freq >= 5) and (not w in most_freq)]
vocab_size = len(vocab)
print("Vocaulary size:",vocab_size)
# Out:
# Vocaulary size: 319

# %%
# create document-word dictionary
word_doc_list = defaultdict(set)

for i in range(len(doc_content_list)):
    doc_words = doc_content_list[i]
    words = doc_words.split()
    for word in words:
      word_doc_list[word].add(i)

# calculate term frequency
word_doc_freq = {}
for word, doc_list in word_doc_list.items():
    word_doc_freq[word] = len(doc_list)
    
# word-index mapping
word_id_map = {}
for i in range(vocab_size):
    word_id_map[vocab[i]] = i
    
# inverse mapping
inv_word_mapping = {v+train_size:i for i,v in word_id_map.items()}

# %% [markdown]
# ## Word-word interaction graph

# %%
# word co-occurence with context windows
# store words in the same window
window_size = 5
windows = []

for doc_words in doc_content_list:
    words = doc_words.split()
    length = len(words)
    if length <= window_size:
        windows.append(words)
    else:
        for j in range(length - window_size + 1):
            window = words[j: j + window_size]
            windows.append(window)

# calculate p(word)
word_window_freq = {}
for window in windows:
    appeared = set()
    for i in range(len(window)):
        word = window[i]
        # continue if the frequency of the word has been calculated
        if word in appeared:
            continue
        if word in word_window_freq:
            word_window_freq[word] += 1
        else:
            word_window_freq[word] = 1
        appeared.add(word)

# calculate co-occurrence frequency (i.e., p(i,j))
word_pair_count = {}
for window in windows:
    for i in range(1, len(window)):
        for j in range(0, i):
            word_i = window[i]
            word_j = window[j]
            if (not word_i in vocab) or (not word_j in vocab):
                continue
            
            word_i_id = word_id_map[word_i]
            word_j_id = word_id_map[word_j]
            if word_i_id == word_j_id:
                continue
            word_pair_str = str(word_i_id) + ',' + str(word_j_id)
            if word_pair_str in word_pair_count:
                word_pair_count[word_pair_str] += 1
            else:
                word_pair_count[word_pair_str] = 1
            # two orders
            word_pair_str = str(word_j_id) + ',' + str(word_i_id)
            if word_pair_str in word_pair_count:
                word_pair_count[word_pair_str] += 1
            else:
                word_pair_count[word_pair_str] = 1

# %% [markdown]
# ## Creating wor-word edges and calculate edge weights

# %%
row = []
col = []
weight = []

# pmi as weights

num_window = len(windows)

for key in word_pair_count:
    temp = key.split(',')
    i = int(temp[0])
    j = int(temp[1])
    count = word_pair_count[key]
    word_freq_i = word_window_freq[vocab[i]]
    word_freq_j = word_window_freq[vocab[j]]
    # PMI = p(i,j) / (p(i)*p(j))
    pmi = np.log((count / num_window) /
              (word_freq_i * word_freq_j/(num_window * num_window)))
    if pmi <= 0:
        continue
    row.append(train_size + i)
    col.append(train_size + j)
#     row.append(train_size + j)
#     col.append(train_size + i)

    weight.append(pmi)
#     weight.append(pmi)
    
print("Number of edges:",len(row))
# Out:
# Number of edges: 5384

# %% [markdown]
# ### Word-word graph with networkx

# %%
G = nx.DiGraph()

for source, target, edge_weight in zip(row,col,weight):
    G.add_edge(source, target, weight=edge_weight)

# %% [markdown]
# ## Problem 1: Statistics of graph
# * Please calculate the number of nodes and number of edges
# * Please calculate the average degree of the graph (i.e., $|E|/|V|$)
# * Use networkx, find out the top-10 words with the highest degree

# %%
print(f"Number of nodes:{G.number_of_nodes()}")
print(f"Number of edges:{G.number_of_edges()}")
print(f"Average degree:{G.number_of_edges() / G.number_of_nodes():.4f}")

sorted(nx.degree(G), key=lambda x: x[1], reverse=True)[:10]
######################################
# Out:
# Number of nodes:319
# Number of edges:5384
# Average degree:16.8777
# [(883, 144),
#  (846, 140),
#  (875, 104),
#  (928, 104),
#  (914, 100),
#  (1044, 98),
#  (881, 96),
#  (848, 94),
#  (847, 94),
#  (901, 92)]

# %%
degree_list = list(tuple(G.degree()))
sorted_degree = sorted(degree_list,key=lambda x:-x[1])

# %%
for k, (node_id, deg) in enumerate(sorted_degree[:10]):
    print(f"Top-{k+1} degree word:\n \t[{inv_word_mapping[node_id]}] with degree {deg}")
# Out:
# Top-1 degree word:
#  	[for] with degree 144
# Top-2 degree word:
#  	[of] with degree 140
# Top-3 degree word:
#  	[just] with degree 104
# Top-4 degree word:
#  	[–] with degree 104
# Top-5 degree word:
#  	[is] with degree 100
# Top-6 degree word:
#  	[clinton] with degree 98
# Top-7 degree word:
#  	[after] with degree 96
# Top-8 degree word:
#  	[says] with degree 94
# Top-9 degree word:
#  	[and] with degree 94
# Top-10 degree word:
#  	[with] with degree 92

# %% [markdown]
# ## Problem 2: Subgraph Visualization
# Visualize a word with degree around 20

# %%
import matplotlib.pyplot as plt

# %%
target_nodeid = sorted_degree[160][0]
subgraph_nodes = [target_nodeid] + list(G.neighbors(target_nodeid))

# assign label dict
labeldict = {index:inv_word_mapping[index] for index in subgraph_nodes}

sub_G = nx.subgraph(G,subgraph_nodes)
######################################

# %%
plt.figure(figsize=(20,15))
configs = dict(
    labels=labeldict,
    node_size=2000,
    node_color="deepskyblue",
    font_size=20,
)
nx.draw_networkx(sub_G,**configs)

# %% [markdown]
# ## Create Document-word edges

# %%
# doc word frequency
doc_word_freq = defaultdict(lambda:0)

for doc_id in document_ids:
    doc_words = doc_content_list[doc_id]
    words = [w for w in doc_words.split() if w in vocab]
    for word in words:
        if word in remove_words: continue
        word_id = word_id_map[word]
        doc_word_str = str(doc_id) + ',' + str(word_id)
        doc_word_freq[doc_word_str] += 1

for doc_index in document_ids:
    doc_words = doc_content_list[doc_index]
    
    # avoid repeated calculation
    words = set(doc_words.split()) & set(vocab)
    for word in words:
        word_index = word_id_map[word]
        key = str(doc_index) + ',' + str(word_index)
        freq = doc_word_freq[key]
        if doc_index < train_size:
            row.append(doc_index)
        else:
            row.append(doc_index + vocab_size)
        col.append(train_size + word_index)
        
        # TF-IDF as edge weight
        idf = np.log(1.0 * len(document_ids) /
                  word_doc_freq[vocab[word_index]])
        weight.append(freq * idf) # TF*IDF

# %% [markdown]
# ### Storing all data in `pyg_data`

# %%
from torch_geometric.data import Data
import scipy.sparse as sp
from torch_geometric.utils import from_scipy_sparse_matrix
import torch

# %%
# create a empty Data object
pyg_data = Data()
pyg_data
# Out:
# Data()

# %%
# nodes
node_size = train_size + vocab_size + test_size
pyg_data.num_nodes = node_size
pyg_data.num_classes = 1

# edges
adj = sp.csr_matrix(
    (weight, (row, col)), shape=(node_size, node_size))
adj = adj + adj.T.multiply(adj.T > adj) - adj.multiply(adj.T > adj) # symmetric

edge_index, edge_weight = from_scipy_sparse_matrix(adj)
pyg_data.edge_index = edge_index.long()
pyg_data.edge_weight = edge_weight.float()

# %%
# masks for training, testing
train_masks = torch.zeros(node_size).bool()
train_masks[:train_size] = 1
test_masks = torch.zeros(node_size).bool()
test_masks[-test_size:] = 1 

pyg_data.train_mask = train_masks
pyg_data.test_mask = test_masks

# labels
targets = [torch.FloatTensor(train_target), torch.zeros(vocab_size), torch.FloatTensor(test_target)]
targets = torch.cat(targets,dim=0).long()
pyg_data.target = targets
assert targets.shape[0] == pyg_data.num_nodes

# initial node feature
node_feature = torch.eye(pyg_data.num_nodes)
pyg_data.x = node_feature

# %%
pyg_data
# Out:
# Data(num_nodes=1375, num_classes=1, edge_index=[2, 10326], edge_weight=[10326], train_mask=[1375], test_mask=[1375], target=[1375], x=[1375, 1375])

# %% [markdown]
# ## Probelm 3: Training classification model

# %%
from torch_geometric.nn import GCNConv
import torch.nn.functional as F
import torch.nn as nn
import torch

# %%
class TextGCN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, out_channels)

    def forward(self, x, edge_index, edge_weight=None):
        x = F.dropout(x, p=0.1, training=self.training)
        x = self.conv1(x, edge_index, edge_weight).relu()
        x = F.dropout(x, p=0.1, training=self.training)
        x = self.conv2(x, edge_index, edge_weight)
        return x#.flatten()

# %%
# model configurations
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dim = 200
model = TextGCN(pyg_data.num_nodes, dim, pyg_data.num_classes).to(device)
optimizer = torch.optim.Adam(model.parameters(),lr=1e-4)
criterion = nn.BCEWithLogitsLoss(reduction="none")
print(model)
# Out:
# TextGCN(
#   (conv1): GCNConv(1375, 200)
#   (conv2): GCNConv(200, 1)
# )

# %%
# map data to GPU device
pyg_data.x = pyg_data.x.to(device)
pyg_data.edge_index = pyg_data.edge_index.to(device)
pyg_data.edge_weight = pyg_data.edge_weight.to(device)
pyg_data.target = pyg_data.target.to(device).float()

# %%
for epoch in range(1000):
    logits = model(pyg_data.x, pyg_data.edge_index, pyg_data.edge_weight).flatten()
    loss = criterion(logits, pyg_data.target)[pyg_data.train_mask]
    loss = loss.mean()    
    
    # Backward and optimize
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    # evaluation
    # calculate the train/test accuracy
    probs = torch.sigmoid(logits)
    accurate_prediction = ((probs>0.5)*1 == pyg_data.target)
    train_accuracy = accurate_prediction[pyg_data.train_mask].float().mean().item()
    test_accuracy = accurate_prediction[pyg_data.test_mask].float().mean().item()
    print(f"Train Accuracy:{train_accuracy:.4f} | Test Accuracy:{test_accuracy:.4f}")
# Out:
# Train Accuracy:0.8389 | Test Accuracy:0.7358
# Train Accuracy:0.8424 | Test Accuracy:0.7170
# Train Accuracy:0.8424 | Test Accuracy:0.7217
# Train Accuracy:0.8460 | Test Accuracy:0.7217
# Train Accuracy:0.8353 | Test Accuracy:0.7358
# Train Accuracy:0.8495 | Test Accuracy:0.7217
# Train Accuracy:0.8318 | Test Accuracy:0.7170
# Train Accuracy:0.8602 | Test Accuracy:0.7311
# Train Accuracy:0.8472 | Test Accuracy:0.7264
# Train Accuracy:0.8389 | Test Accuracy:0.7264
# Train Accuracy:0.8436 | Test Accuracy:0.7217
# Train Accuracy:0.8365 | Test Accuracy:0.7311
# Train Accuracy:0.8377 | Test Accuracy:0.7358
# Train Accuracy:0.8436 | Test Accuracy:0.7500
# Train Accuracy:0.8519 | Test Accuracy:0.7358
# Train Accuracy:0.8483 | Test Accuracy:0.7406
# Train Accuracy:0.8389 | Test Accuracy:0.7311
# Train Accuracy:0.9123 | Test Accuracy:0.7689
# Train Accuracy:0.9088 | Test Accuracy:0.7453
# Train Accuracy:0.9111 | Test Accuracy:0.7594
# Train Accuracy:0.9135 | Test Accuracy:0.7594
# Train Accuracy:0.9052 | Test Accuracy:0.7500
# Train Accuracy:0.9111 | Test Accuracy:0.7594
# Train Accuracy:0.9147 | Test Accuracy:0.7547
# Train Accuracy:0.9111 | Test Accuracy:0.7406
# Train Accuracy:0.9123 | Test Accuracy:0.7594
# Train Accuracy:0.9218 | Test Accuracy:0.7594
# Train Accuracy:0.9123 | Test Accuracy:0.7594
# Train Accuracy:0.9147 | Test Accuracy:0.7453
# Train Accuracy:0.9111 | Test Accuracy:0.7500
# Train Accuracy:0.9088 | Test Accuracy:0.7594
# Train Accuracy:0.9100 | Test Accuracy:0.7642
# Train Accuracy:0.9135 | Test Accuracy:0.7547
# Train Accuracy:0.9147 | Test Accuracy:0.7642
# Train Accuracy:0.9111 | Test Accuracy:0.7547
# Train Accuracy:0.9147 | Test Accuracy:0.7642
# Train Accuracy:0.9159 | Test Accuracy:0.7594
# Train Accuracy:0.9182 | Test Accuracy:0.7594
# Train Accuracy:0.9182 | Test Accuracy:0.7594
# Train Accuracy:0.9218 | Test Accuracy:0.7547
# Train Accuracy:0.9147 | Test Accuracy:0.7594
# Train Accuracy:0.9135 | Test Accuracy:0.7594
# Train Accuracy:0.9147 | Test Accuracy:0.7547
# Train Accuracy:0.9135 | Test Accuracy:0.7500
# Train Accuracy:0.9123 | Test Accuracy:0.7500
# Train Accuracy:0.9100 | Test Accuracy:0.7547
# Train Accuracy:0.9064 | Test Accuracy:0.7500
# Train Accuracy:0.9111 | Test Accuracy:0.7594
# Train Accuracy:0.9123 | Test Accuracy:0.7406
# Train Accuracy:0.9147 | Test Accuracy:0.7642
# Train Accuracy:0.9171 | Test Accuracy:0.7594
# Train Accuracy:0.9171 | Test Accuracy:0.7547
# Train Accuracy:0.9159 | Test Accuracy:0.7642
# Train Accuracy:0.9194 | Test Accuracy:0.7453
# Train Accuracy:0.9159 | Test Accuracy:0.7547
# Train Accuracy:0.9100 | Test Accuracy:0.7453
# Train Accuracy:0.9147 | Test Accuracy:0.7547
# Train Accuracy:0.9147 | Test Accuracy:0.7642
# Train Accuracy:0.9064 | Test Accuracy:0.7500
# Train Accuracy:0.9159 | Test Accuracy:0.7594
# Train Accuracy:0.9171 | Test Accuracy:0.7547
# Train Accuracy:0.9194 | Test Accuracy:0.7500
# Train Accuracy:0.9159 | Test Accuracy:0.7594
# Train Accuracy:0.9194 | Test Accuracy:0.7594
# Train Accuracy:0.9100 | Test Accuracy:0.7642
# Train Accuracy:0.9242 | Test Accuracy:0.7453
# Train Accuracy:0.9147 | Test Accuracy:0.7594

# %% [markdown]
# ## Explain your prediction via data visualization with GNNExplainer

# %%
from torch_geometric.nn import GNNExplainer
import matplotlib.pyplot as plt

# %%
# use target as node color
colors = pyg_data.target
overall_labels = {i:f"Doc_{i}" for i in range(node_size)}
overall_labels.update(inv_word_mapping)

# %%
vocab_nodes = list(range(train_size+vocab_size))
logits = model(pyg_data.x, pyg_data.edge_index, pyg_data.edge_weight).flatten()
probs = torch.sigmoid(logits)
probs[vocab_nodes] = 0.5 # masking training nodes, do not change this line
values,indices = torch.topk(probs,20,largest=True)

# %% [markdown]
# ### Find document index with top-20 highest probability of being fake news

# %%
print("-------------Document index with highest predicted probability in testing set.")
for node_idx in indices.cpu().numpy():
    explainer = GNNExplainer(model, epochs=20, return_type='raw',lr=1e-3,log=False)
    node_feat_mask, edge_mask = explainer.explain_node(int(node_idx), pyg_data.x, pyg_data.edge_index,
                                                   edge_weight=pyg_data.edge_weight)
    print(f"Document index:{node_idx} | Predicted prob: {probs[node_idx].item():.4f} | Number of nodes:",edge_mask.bool().sum().item())
# Out:
# -------------Document index with highest predicted probability in testing set.
# Document index:1228 | Predicted prob: 0.9543 | Number of nodes: 2778
# Document index:1198 | Predicted prob: 0.9493 | Number of nodes: 322
# Document index:1358 | Predicted prob: 0.9372 | Number of nodes: 730
# Document index:1310 | Predicted prob: 0.9370 | Number of nodes: 816
# Document index:1175 | Predicted prob: 0.9348 | Number of nodes: 1092
# Document index:1203 | Predicted prob: 0.9278 | Number of nodes: 1276
# Document index:1215 | Predicted prob: 0.9209 | Number of nodes: 140
# Document index:1316 | Predicted prob: 0.9187 | Number of nodes: 980
# Document index:1281 | Predicted prob: 0.9124 | Number of nodes: 1404
# Document index:1269 | Predicted prob: 0.9115 | Number of nodes: 222
# Document index:1171 | Predicted prob: 0.9101 | Number of nodes: 550
# Document index:1350 | Predicted prob: 0.8866 | Number of nodes: 306
# Document index:1299 | Predicted prob: 0.8803 | Number of nodes: 780
# Document index:1248 | Predicted prob: 0.8633 | Number of nodes: 1528
# Document index:1259 | Predicted prob: 0.8620 | Number of nodes: 20
# Document index:1334 | Predicted prob: 0.8576 | Number of nodes: 118
# Document index:1349 | Predicted prob: 0.8549 | Number of nodes: 76
# Document index:1366 | Predicted prob: 0.8510 | Number of nodes: 584
# Document index:1288 | Predicted prob: 0.8506 | Number of nodes: 406
# Document index:1192 | Predicted prob: 0.8483 | Number of nodes: 818

# %%
# train explainer
explainer = GNNExplainer(model, epochs=20, return_type='raw',lr=1e-3)
node_idx = 1215  # you can change the index according to the index above
node_feat_mask, edge_mask = explainer.explain_node(node_idx, pyg_data.x, pyg_data.edge_index,
                                                   edge_weight=pyg_data.edge_weight)

# convert index to label
subgraph_nodes = pyg_data.edge_index[:,edge_mask.bool()].detach().cpu().numpy().flatten()
subgraph_labels = {i:overall_labels[i] for i in subgraph_nodes}


# draw plots
plt.figure(figsize=(13,10))
probs = torch.sigmoid(logits)[node_idx].item()
answer = "Real" if pyg_data.target[node_idx].item() == 0 else "Fake"
ax, G = explainer.visualize_subgraph(node_idx, pyg_data.edge_index, edge_mask, y=pyg_data.target,labels=subgraph_labels)
plt.title(f"Node:{subgraph_labels[node_idx]} with probability:{probs:.2f} Ground truth:{answer}")
plt.show()
# Out:
# Explain node 1215: 100%|██████████| 20/20 [00:00<00:00, 160.79it/s]

# %% [markdown]
# ### Find document index with top-20 lowest probability of being fake news

# %%
vocab_nodes = list(range(train_size+vocab_size))
logits = model(pyg_data.x, pyg_data.edge_index, pyg_data.edge_weight).flatten()
probs = torch.sigmoid(logits)
probs[vocab_nodes] = 0.5
values,indices = torch.topk(probs,20,largest=False)

# %%
print("-------------Document index with lowest predicted probability in testing set.")
for node_idx in indices.cpu().numpy():
    explainer = GNNExplainer(model, epochs=20, return_type='raw',lr=1e-3,log=False)
    node_feat_mask, edge_mask = explainer.explain_node(int(node_idx), pyg_data.x, pyg_data.edge_index,
                                                   edge_weight=pyg_data.edge_weight)
    print(f"Document index:{node_idx} | Predicted prob: {probs[node_idx].item():.4f} | Number of nodes:",edge_mask.bool().sum().item())
# Out:
# -------------Document index with lowest predicted probability in testing set.
# Document index:1367 | Predicted prob: 0.0342 | Number of nodes: 692
# Document index:1190 | Predicted prob: 0.0401 | Number of nodes: 222
# Document index:1178 | Predicted prob: 0.0402 | Number of nodes: 222
# Document index:1333 | Predicted prob: 0.0402 | Number of nodes: 222
# Document index:1302 | Predicted prob: 0.0402 | Number of nodes: 222
# Document index:1374 | Predicted prob: 0.0448 | Number of nodes: 462
# Document index:1183 | Predicted prob: 0.0537 | Number of nodes: 414
# Document index:1233 | Predicted prob: 0.0569 | Number of nodes: 368
# Document index:1176 | Predicted prob: 0.0571 | Number of nodes: 448
# Document index:1331 | Predicted prob: 0.0590 | Number of nodes: 406
# Document index:1282 | Predicted prob: 0.0641 | Number of nodes: 32
# Document index:1242 | Predicted prob: 0.0641 | Number of nodes: 32
# Document index:1289 | Predicted prob: 0.0645 | Number of nodes: 32
# Document index:1369 | Predicted prob: 0.0647 | Number of nodes: 32
# Document index:1301 | Predicted prob: 0.0657 | Number of nodes: 376
# Document index:1303 | Predicted prob: 0.0666 | Number of nodes: 312
# Document index:1284 | Predicted prob: 0.0686 | Number of nodes: 142
# Document index:1292 | Predicted prob: 0.0725 | Number of nodes: 432
# Document index:1181 | Predicted prob: 0.0726 | Number of nodes: 182
# Document index:1337 | Predicted prob: 0.0807 | Number of nodes: 332

# %%
# train explainer
explainer = GNNExplainer(model, epochs=20, return_type='raw',lr=1e-3)
node_idx = 1190
node_feat_mask, edge_mask = explainer.explain_node(node_idx, pyg_data.x, pyg_data.edge_index,
                                                   edge_weight=pyg_data.edge_weight)

# convert index to label
subgraph_nodes = pyg_data.edge_index[:,edge_mask.bool()].detach().cpu().numpy().flatten()
subgraph_labels = {i:overall_labels[i] for i in subgraph_nodes}


# draw plots
plt.figure(figsize=(13,10))
probs = torch.sigmoid(logits)[node_idx].item()
answer = "Real" if pyg_data.target[node_idx].item() == 0 else "Fake"
ax, G = explainer.visualize_subgraph(node_idx, pyg_data.edge_index, edge_mask, y=pyg_data.target,labels=subgraph_labels)
plt.title(f"Node:{subgraph_labels[node_idx]} with probability:{probs:.2f} Ground truth:{answer}")
plt.show()
# Out:
# Explain node 1190: 100%|██████████| 20/20 [00:00<00:00, 215.92it/s]
